# %%
import numpy as np
import matplotlib.pyplot as plt
import json

classifier = MNISTClassifier()
classifier.load_data("mnist_train.npz", "mnist_test.npz")
classifier.load_model("mnist_mlp_pretty.json")
# Out:
# ✅ Datos cargados exitosamente
# Entrenamiento - Imágenes: (60000, 28, 28), Etiquetas: (60000,)
# Prueba - Imágenes: (10000, 28, 28), Etiquetas: (10000,)
# ✅ Modelo cargado exitosamente
# Forma de entrada: [28, 28]
# Preprocesamiento - escala: 255.0
# Número de capas: 2
# Capa 1: 128 neuronas, activación: relu
#   - Pesos: (784, 128)
#   - Sesgos: (128,)
# Capa 2: 10 neuronas, activación: softmax
#   - Pesos: (128, 10)
#   - Sesgos: (10,)

# %%
# Esto hace exactamente lo del ejercicio: mostrar 16 imágenes
classifier.visualize_test_grid(16)

# %%
# Esto es EXTRA: ver cómo predice el modelo
classifier.test_predictions(10)

# %%
# Esto es EXTRA: ver cómo predice el modelo
classifier.test_predictions(10)
