# %%
# %run evaluar_pretrained.py
# Out:
# 🔍 PARTE 3: EVALUACIÓN MODELO PRE-ENTRENADO
# =======================================================
# 📊 Arquitectura del modelo pre-entrenado:
#    Input shape: [28, 28]
#    Preprocess: scale=255.0
#    Capa 1: 128 neuronas, activación: relu
#    Capa 2: 10 neuronas, activación: softmax
# ✅ Modelo pre-entrenado cargado exitosamente
# ✅ Datos de prueba cargados: (10000, 28, 28)
#
# 🧮 Evaluando precisión del modelo pre-entrenado...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /app/evaluar_pretrained.py:130
#     127     print(f"\n✅ Parte 3 completada. Precisión: {accuracy*100:.2f}%")
#     129 if __name__ == "__main__":
# --> 130     main()
#
# File /app/evaluar_pretrained.py:122, in main()
#     119 evaluator.load_test_data()
#     121 # 3. Evaluar precisión (debe ser >90%)
# --> 122 accuracy = evaluator.evaluate_accuracy()
#     124 # 4. Visualizar predicciones
#     125 evaluator.visualize_predictions()
#
# File /app/evaluar_pretrained.py:69, in MNISTPretrainedEvaluator.evaluate_accuracy(self)
#      67 activations = [self.X_test]
#      68 for layer in self.layers:
# ---> 69     activations.append(layer.forward(activations[-1]))
#      71 output = activations[-1]
#      72 predictions = np.argmax(output, axis=1)
#
# RuntimeError: Dot: shape mismatch.

# %%
% run evaluar_pretrained.py
# Out:
# UsageError: Line magic function `%` not found.

# %%
# %run evaluar_pretrained.py
# Out:
# 🔍 PARTE 3: EVALUACIÓN MODELO PRE-ENTRENADO
# =======================================================
# 📊 Arquitectura del modelo pre-entrenado:
#    Input shape: [28, 28]
#    Preprocess: scale=255.0
#    Capa 1: 128 neuronas, activación: relu
#    Capa 2: 10 neuronas, activación: softmax
# ✅ Modelo pre-entrenado cargado exitosamente
# ✅ Datos de prueba cargados: (10000, 28, 28)
#
# 🧮 Evaluando precisión del modelo pre-entrenado...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /app/evaluar_pretrained.py:129
#     126     print(f"\n✅ Parte 3 completada. Precisión: {accuracy*100:.2f}%")
#     128 if __name__ == "__main__":
# --> 129     main()
#
# File /app/evaluar_pretrained.py:121, in main()
#     118 evaluator.load_test_data()
#     120 # 3. Evaluar precisión (debe ser >90%)
# --> 121 accuracy = evaluator.evaluate_accuracy()
#     123 # 4. Visualizar predicciones
#     124 evaluator.visualize_predictions()
#
# File /app/evaluar_pretrained.py:68, in MNISTPretrainedEvaluator.evaluate_accuracy(self)
#      66 activations = [self.X_test_flat]
#      67 for layer in self.layers:
# ---> 68     activations.append(layer.forward(activations[-1]))
#      70 output = activations[-1]
#      71 predictions = np.argmax(output, axis=1)
#
# RuntimeError: Dot: shape mismatch.

# %%
# %run evaluar_pretrained.py
# Out:
# 🔍 PARTE 3: EVALUACIÓN MODELO PRE-ENTRENADO
# =======================================================
# 📊 Arquitectura del modelo pre-entrenado:
#    Input shape: [28, 28]
#    Preprocess: scale=255.0
#    Capa 1: 128 neuronas, activación: relu
#      Pesos: (128, 784), Sesgos: (128,)
#    Capa 2: 10 neuronas, activación: softmax
#      Pesos: (10, 128), Sesgos: (10,)
# ✅ Modelo pre-entrenado cargado exitosamente
# ✅ Datos de prueba cargados: (10000, 28, 28)
#    X_test shape: (10000, 784)
#
# 🧮 Evaluando precisión del modelo pre-entrenado...
#    Capa 1 - Input: (10000, 784)
#    Capa 1 - Output: (10000, 128)
#    Capa 2 - Input: (10000, 128)
#    Capa 2 - Output: (10000, 10)
# 🎯 PRECISIÓN DEL MODELO PRE-ENTRENADO: 0.9666 (96.66%)
# ✅ Parte 3 completada. Precisión: 96.66%

# %%
# %run evaluar_pretrained.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File /usr/local/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'evaluar_pretrained.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_line_magic('run', 'evaluar_pretrained.py')
#
# File /usr/local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2482, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2480     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2481 with self.builtin_trap:
# -> 2482     result = fn(*args, **kwargs)
#    2484 # The code below prevents the output from being displayed
#    2485 # when using magics with decorator @output_can_be_silenced
#    2486 # when the last Python token in the expression is a ';'.
#    2487 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/execution.py:731, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     729     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     730         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 731     raise Exception(msg) from e
#     732 except TypeError:
#     733     if fpath in sys.meta_path:
#
# Exception: File `'evaluar_pretrained.py'` not found.

# %%
# %run evaluar_pretrained.py
# Out:
# 🔍 PARTE 3: EVALUACIÓN MODELO PRE-ENTRENADO
# =======================================================
# 📊 Arquitectura del modelo pre-entrenado:
#    Input shape: [28, 28]
#    Preprocess: scale=255.0
#    Capa 1: 128 neuronas, activación: relu
#      Pesos: (128, 784), Sesgos: (128,)
#    Capa 2: 10 neuronas, activación: softmax
#      Pesos: (10, 128), Sesgos: (10,)
# ✅ Modelo pre-entrenado cargado exitosamente
# ✅ Datos de prueba cargados: (10000, 28, 28)
#    X_test shape: (10000, 784)
#
# 🧮 Evaluando precisión del modelo pre-entrenado...
#    Capa 1 - Input: (10000, 784)
#    Capa 1 - Output: (10000, 128)
#    Capa 2 - Input: (10000, 128)
#    Capa 2 - Output: (10000, 10)
# 🎯 PRECISIÓN DEL MODELO PRE-ENTRENADO: 0.9666 (96.66%)
# ✅ Parte 3 completada. Precisión: 96.66%

# %%
# %run parte4_comparativa_fija
# Out:
# PARTE 4: COMPARATIVA DE OPTIMIZADORES
# ============================================================
# Épocas: 10, Batch size: 128
# Optimizadores: SGD, SGD+Momentum, RMSprop, Adam
# Datos MNIST cargados:
#    Entrenamiento: (60000, 784)
#    Prueba: (10000, 784)
#
# ============================================================
# ENTRENANDO CON: SGD
# ============================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:332
#     329     print(f"\nMEJOR OPTIMIZADOR: {best_opt}")
#     331 if __name__ == "__main__":
# --> 332     main()
#
# File /app/parte4_comparativa_fija.py:301, in main()
#     299 # Entrenar con cada optimizador
#     300 for optimizer, name in optimizers:
# --> 301     layers, losses, accuracies, final_acc = train_with_optimizer(
#     302         optimizer, name, X_train, y_train, X_test, y_test, epochs, batch_size
#     303     )
#     305     results[name] = {
#     306         'losses': losses,
#     307         'accuracies': accuracies,
#     308         'final_accuracy': final_acc,
#     309         'layers': layers
#     310     }
#     312     # Guardar modelo
#
# File /app/parte4_comparativa_fija.py:182, in train_with_optimizer(optimizer, optimizer_name, X_train, y_train, X_test, y_test, epochs, batch_size)
#     180 dW2 = np.dot(activations[1].T, dz2)
#     181 db2 = np.sum(dz2, axis=0, keepdims=True)
# --> 182 layers[1].weight_gradients = dW2
#     183 layers[1].bias_gradients = db2
#     185 # Layer 1 gradients
#
# AttributeError: 'DnnLib.DenseLayer' object has no attribute 'weight_gradients'

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model
# ========================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Training with Adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:189
#     186 import os
#     187 os.makedirs("exercise4models", exist_ok=True)
# --> 189 main()
#
# File /app/parte4_comparativa_fija.py:139, in main()
#     136 layer2 = DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     138 # Entrenar por 3 épocas como mostró el instructor
# --> 139 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     141 # Evaluación final
#     142 final_accuracy = evaluate_accuracy(test_images, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:54, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      51 db2 = np.sum(dz2, axis=0, keepdims=True)
#      53 # Layer 1 gradients
# ---> 54 dh1 = np.dot(dz2, layer2.weights.T)
#      55 dz1 = dh1 * (h1 > 0)  # ReLU derivative
#      56 dW1 = np.dot(X.T, dz1)
#
# ValueError: shapes (60000,10) and (128,10) not aligned: 10 (dim 1) != 128 (dim 0)

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Training with Adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:177
#     174     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     176 if __name__ == "__main__":
# --> 177     main()
#
# File /app/parte4_comparativa_fija.py:136, in main()
#     133 layer2 = DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     135 # Entrenar
# --> 136 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     138 # Evaluación final
#     139 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:57, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      53 db2 = np.sum(dz2, axis=0, keepdims=True)  # (1, 10)
#      55 # Capa 1 (ReLU) - CORRECCIÓN IMPORTANTE
#      56 # dz2: (60000, 10), layer2.weights: (128, 10) -> necesitamos (10, 128)
# ---> 57 dh1 = np.dot(dz2, layer2.weights.T)  # (60000, 128)
#      58 dz1 = dh1 * (h1 > 0).astype(float)  # ReLU derivative
#      59 dW1 = np.dot(X.T, dz1)  # (784, 128)
#
# ValueError: shapes (60000,10) and (128,10) not aligned: 10 (dim 1) != 128 (dim 0)

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Training with Adam
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:177
#     174     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     176 if __name__ == "__main__":
# --> 177     main()
#
# File /app/parte4_comparativa_fija.py:136, in main()
#     133 layer2 = DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     135 # Entrenar
# --> 136 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     138 # Evaluación final
#     139 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:57, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      53 db2 = np.sum(dz2, axis=0, keepdims=True)  # (1, 10)
#      55 # Capa 1 (ReLU) - CORRECCIÓN IMPORTANTE
#      56 # dz2: (60000, 10), layer2.weights: (128, 10) -> necesitamos (10, 128)
# ---> 57 dh1 = np.dot(dz2, layer2.weights.T)  # (60000, 128)
#      58 dz1 = dh1 * (h1 > 0).astype(float)  # ReLU derivative
#      59 dW1 = np.dot(X.T, dz1)  # (784, 128)
#
# ValueError: shapes (60000,10) and (128,10) not aligned: 10 (dim 1) != 128 (dim 0)

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Training with Adam
# Debug - layer1.weights shape: (128, 784)
# Debug - layer1.bias shape: (128,)
# Debug - layer2.weights shape: (10, 128)
# Debug - layer2.bias shape: (10,)
# Debug epoch 1 - h1 shape: (60000, 128), output shape: (60000, 10)
# Debug - dz2 shape: (60000, 10)
# Debug - dW2 shape: (128, 10), expected: (10, 128)
# Debug - db2 shape: (1, 10), expected: (10,)
# Debug - About to compute dh1: dz2 (60000, 10) @ layer2.weights.T (128, 10)
# Warning: Dimension mismatch detected!
# layer2.weights shape: (10, 128)
# dz2 shape: (60000, 10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:207
#     204     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     206 if __name__ == "__main__":
# --> 207     main()
#
# File /app/parte4_comparativa_fija.py:166, in main()
#     163 layer2 = DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     165 # Entrenar
# --> 166 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     168 # Evaluación final
#     169 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:84, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      81 else:
#      82     weights_for_backprop = layer2.weights
# ---> 84 dh1 = np.dot(dz2, weights_for_backprop.T)
#      85 dz1 = dh1 * (h1 > 0).astype(float)  # ReLU derivative
#      86 dW1 = np.dot(X.T, dz1)
#
# ValueError: shapes (60000,10) and (128,10) not aligned: 10 (dim 1) != 128 (dim 0)

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Training with Adam
# Debug - layer1.weights shape: (128, 784)
# Debug - layer1.bias shape: (128,)
# Debug - layer2.weights shape: (10, 128)
# Debug - layer2.bias shape: (10,)
# Debug epoch 1 - h1 shape: (60000, 128), output shape: (60000, 10)
# Debug - dz2 shape: (60000, 10)
# Debug - dW2 shape: (10, 128), expected: (10, 128)
# Debug - db2 shape: (10,), expected: (10,)
# Debug - About to compute dh1: dz2 (60000, 10) @ layer2.weights (10, 128)
# Debug - dW1 shape: (128, 784), expected: (128, 784)
# Debug - db1 shape: (128,), expected: (128,)
# Epoch 01 | Loss: 29.6224 | Test Acc: 0.0999
# Debug epoch 2 - h1 shape: (60000, 128), output shape: (60000, 10)
# Debug - dz2 shape: (60000, 10)
# Debug - dW2 shape: (10, 128), expected: (10, 128)
# Debug - db2 shape: (10,), expected: (10,)
# Debug - About to compute dh1: dz2 (60000, 10) @ layer2.weights (10, 128)
# Debug - dW1 shape: (128, 784), expected: (128, 784)
# Debug - db1 shape: (128,), expected: (128,)
# Epoch 02 | Loss: 29.5532 | Test Acc: 0.1001
# Debug epoch 3 - h1 shape: (60000, 128), output shape: (60000, 10)
# Debug - dz2 shape: (60000, 10)
# Debug - dW2 shape: (10, 128), expected: (10, 128)
# Debug - db2 shape: (10,), expected: (10,)
# Debug - About to compute dh1: dz2 (60000, 10) @ layer2.weights (10, 128)
# Debug - dW1 shape: (128, 784), expected: (128, 784)
# Debug - db1 shape: (128,), expected: (128,)
# Epoch 03 | Loss: 29.4797 | Test Acc: 0.1017
#
# 🎯 Test Accuracy: 0.1017 (10.17%)
# 💾 Model exported to exercise4models/mnist_mlp_own_model.json
#
# Epoch 01 | Loss: 29.6224 | Test Acc: 0.0999
# Epoch 02 | Loss: 29.5532 | Test Acc: 0.1001
# Epoch 03 | Loss: 29.4797 | Test Acc: 0.1017
#
# Test Accuracy: 0.1017

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Training with Adam
# Epoch 01 | Loss: 19.6993 | Test Acc: 0.5441
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:203
#     200     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     202 if __name__ == "__main__":
# --> 203     main()
#
# File /app/parte4_comparativa_fija.py:162, in main()
#     159 layer2 = DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     161 # Entrenar
# --> 162 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     164 # Evaluación final
#     165 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:55, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      52 t += 1
#      54 # Forward pass
# ---> 55 h1 = layer1.forward(X_batch)
#      56 output = layer2.forward(h1)
#      58 # Compute loss
#
# KeyboardInterrupt:

# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO MEJORADO (Como el Ing. Deras)
# ==================================================
# ✅ Datos cargados
# ✅ Pesos inicializados con He Initialization
# 🚀 Entrenamiento MEJORADO (3 épocas)
#    Arquitectura: 784 -> 256 -> 10
#    Batch size: 128
#    Learning rate: 0.0005
# 📊 Época 1/3 - Loss: 0.4106 - Train Acc: 0.9397 - Test Acc: 0.9384
# 📊 Época 2/3 - Loss: 0.1907 - Train Acc: 0.9584 - Test Acc: 0.9550
# 📊 Época 3/3 - Loss: 0.1399 - Train Acc: 0.9684 - Test Acc: 0.9624
#
# 🎉 PRECISIÓN FINAL: 0.9624 (96.24%)
# ✅ Modelo guardado como mi_modelo_mejorado.json
# ✅ ¡Listo para comparar con el Ing.!

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Layer1 weights shape: (128, 784)
# Layer2 weights shape: (10, 128)
# Training with Adam
# Batch size: 128, Number of batches: 468
# Epoch 01 | Loss: 6.4052 | Test Acc: 0.7903
# Epoch 02 | Loss: 2.4192 | Test Acc: 0.8518
# Epoch 03 | Loss: 1.7617 | Test Acc: 0.8796
#
# 🎯 Test Accuracy: 0.8796 (87.96%)
# 💾 Model exported to exercise4models/mnist_mlp_own_model.json
#
# Epoch 01 | Loss: 6.4052 | Test Acc: 0.7903
# Epoch 02 | Loss: 2.4192 | Test Acc: 0.8518
# Epoch 03 | Loss: 1.7617 | Test Acc: 0.8796
#
# Test Accuracy: 0.8796

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with DnnLib Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Data types: X=float64, y=float64
# Layer1 weights shape: (128, 784)
# Layer2 weights shape: (10, 128)
# Training with DnnLib Adam optimizer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:150
#     147     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     149 if __name__ == "__main__":
# --> 150     main()
#
# File /app/parte4_comparativa_fija.py:109, in main()
#     106 print(f"Layer2 weights shape: {layer2.weights.shape}")
#     108 # Entrenar
# --> 109 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     111 # Evaluación final
#     112 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:13, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      10 print("Training with DnnLib Adam optimizer")
#      12 # Usar el optimizador Adam nativo de DnnLib
# ---> 13 optimizer = DnnLib.Adam(learning_rate=0.001)
#      15 loss_history = []
#      16 acc_history = []
#
# AttributeError: module 'DnnLib' has no attribute 'Adam'

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Available DnnLib attributes:
# ['ActivationType', 'DenseLayer', 'RELU', 'SIGMOID', 'SOFTMAX', 'TANH', 'apply_activation', 'apply_activation_derivative', 'relu', 'relu_derivative', 'sigmoid', 'sigmoid_derivative', 'softmax', 'softmax_derivative', 'tanh', 'tanh_derivative']
#
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Data types: X=float64, y=float64
# Layer1 weights shape: (128, 784)
# Layer2 weights shape: (10, 128)
# Training with manual Adam + DnnLib functions
# Batch size: 128, Number of batches: 468
# Epoch 01 | Loss: 9.8431 | Test Acc: 0.7987
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:221
#     218     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     220 if __name__ == "__main__":
# --> 221     main()
#
# File /app/parte4_comparativa_fija.py:180, in main()
#     177 print(f"Layer2 weights shape: {layer2.weights.shape}")
#     179 # Entrenar
# --> 180 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     182 # Evaluación final
#     183 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:57, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      54 t += 1
#      56 # Forward pass
# ---> 57 h1 = layer1.forward(X_batch)
#      58 output = layer2.forward(h1)
#      60 # Compute loss usando DnnLib si está disponible, sino manual
#
# KeyboardInterrupt:

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with DnnLib Adam
# ==================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Data types: X=float64, y=float64
# Layer1 weights shape: (128, 784)
# Layer2 weights shape: (10, 128)
# Training with DnnLib Adam optimizer
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:148
#     145     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     147 if __name__ == "__main__":
# --> 148     main()
#
# File /app/parte4_comparativa_fija.py:107, in main()
#     104 print(f"Layer2 weights shape: {layer2.weights.shape}")
#     106 # Entrenar
# --> 107 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     109 # Evaluación final
#     110 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:13, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      10 print("Training with DnnLib Adam optimizer")
#      12 # Usar el optimizador Adam nativo de DnnLib (como en el manual)
# ---> 13 optimizer = DnnLib.Adam(learning_rate=0.001)
#      15 loss_history = []
#      16 acc_history = []
#
# AttributeError: module 'DnnLib' has no attribute 'Adam'

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model with Adam
# ==================================================
# Available DnnLib attributes:
#   - ActivationType
#   - DenseLayer
#   - RELU
#   - SIGMOID
#   - SOFTMAX
#   - TANH
#   - apply_activation
#   - apply_activation_derivative
#   - relu
#   - relu_derivative
#   - sigmoid
#   - sigmoid_derivative
#   - softmax
#   - softmax_derivative
#   - tanh
#   - tanh_derivative
#
# Function availability:
#   - DnnLib.Adam: ✗
#   - DnnLib.SGD: ✗
#   - DnnLib.RMSprop: ✗
#   - DnnLib.cross_entropy: ✗
#   - DnnLib.cross_entropy_gradient: ✗
#   - DnnLib.mse: ✗
#   - DnnLib.mse_gradient: ✗
#
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Layer1 weights shape: (128, 784)
# Layer2 weights shape: (10, 128)
# Training with manual Adam optimizer (optimized)
# Batch size: 128
# Epoch 01 | Loss: 10.3201 | Test Acc: 0.7883
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:232
#     229     print(f"\nTest Accuracy: {final_accuracy:.4f}")
#     231 if __name__ == "__main__":
# --> 232     main()
#
# File /app/parte4_comparativa_fija.py:191, in main()
#     188 print(f"Layer2 weights shape: {layer2.weights.shape}")
#     190 # Entrenar
# --> 191 loss_history, accuracy_history = train_network(layer1, layer2, X, y, X_test, test_labels, epochs=3)
#     193 # Evaluación final
#     194 final_accuracy = evaluate_accuracy(X_test, test_labels, layer1, layer2)
#
# File /app/parte4_comparativa_fija.py:72, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#      69 t += 1
#      71 # Forward pass
# ---> 72 h1 = layer1.forward(X_batch)
#      73 output = layer2.forward(h1)
#      75 # Compute loss - usar DnnLib si disponible, sino manual
#
# KeyboardInterrupt:

# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO CON ADAM OPTIMIZER
# ==================================================
# Arquitectura: 784 -> 128 -> 10
# Optimizador: Adam (learning_rate=0.001)
# Batch size: 128
# Épocas: 3
# ==================================================
# ✅ Datos MNIST cargados:
#    Entrenamiento: (60000, 784)
#    Prueba: (10000, 784)
# 🚀 Entrenando con Adam Optimizer
# ==================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:204
#     201     print("✅ Entrenamiento completado exitosamente!")
#     203 if __name__ == "__main__":
# --> 204     main()
#
# File /app/parte4_comparativa_fija.py:179, in main()
#     173 layers = [
#     174     DnnLib.DenseLayer(784, 128, DnnLib.ActivationType.RELU),
#     175     DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     176 ]
#     178 # 3. Entrenar con Adam
# --> 179 loss_history, acc_history = train_with_adam(
#     180     layers, X_train, y_train, X_test, y_test, epochs=3, batch_size=128
#     181 )
#     183 # 4. Evaluación final
#     184 final_accuracy = evaluate_accuracy(layers, X_test, y_test)
#
# File /app/parte4_comparativa_fija.py:89, in train_with_adam(layers, X_train, y_train, X_test, y_test, epochs, batch_size)
#      86 output = activations[-1]
#      88 # Compute loss
# ---> 89 loss = DnnLib.cross_entropy(output, y_batch)
#      90 epoch_loss += loss
#      92 # Backward pass
#
# AttributeError: module 'DnnLib' has no attribute 'cross_entropy'

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model - Optimized for 95% first epoch
# ============================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Data preprocessing: normalized + centered
# Architecture: 784 -> 128 (ReLU) -> 10 (Softmax)
# Training with optimized Adam for 95% first epoch
# Optimized settings: LR=0.001, Batch size=64

# %%
# %run parte4_comparativa_fija
# Out:
# Train MNIST MLP model - Optimized for 95% first epoch
# ============================================================
# Loading data...
# Training set: (60000, 784)
# Test set: (10000, 784)
# Data preprocessing: normalized + centered
# Architecture: 784 -> 128 (ReLU) -> 10 (Softmax)
# Training with optimized Adam for 95% first epoch
# Optimized settings: LR=0.001, Batch size=64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:232
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /app/parte4_comparativa_fija.py:191, in main()
#     188 # 5. Guardar modelo
#     189 save_model(layers, "mnist_mlp_own_model.json")
# --> 191 # 6. Mostrar resumen como el Ing. Deras
#     192 print("\n" + "=" * 50)
#     193 print("📊 RESUMEN DEL ENTRENAMIENTO:")
#
# File /app/parte4_comparativa_fija.py:60, in train_network(layer1, layer2, X, y, X_test, y_test, epochs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO CON ADAM OPTIMIZER
# ==================================================
# Arquitectura: 784 -> 128 -> 10
# Optimizador: Adam (learning_rate=0.001)
# Batch size: 128
# Épocas: 3
# ==================================================
# ✅ Datos MNIST cargados:
#    Entrenamiento: (60000, 784)
#    Prueba: (10000, 784)
# 🚀 Entrenando con Adam Optimizer
# ==================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:204
#     201     print("✅ Entrenamiento completado exitosamente!")
#     203 if __name__ == "__main__":
# --> 204     main()
#
# File /app/parte4_comparativa_fija.py:179, in main()
#     173 layers = [
#     174     DnnLib.DenseLayer(784, 128, DnnLib.ActivationType.RELU),
#     175     DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     176 ]
#     178 # 3. Entrenar con Adam
# --> 179 loss_history, acc_history = train_with_adam(
#     180     layers, X_train, y_train, X_test, y_test, epochs=3, batch_size=128
#     181 )
#     183 # 4. Evaluación final
#     184 final_accuracy = evaluate_accuracy(layers, X_test, y_test)
#
# File /app/parte4_comparativa_fija.py:89, in train_with_adam(layers, X_train, y_train, X_test, y_test, epochs, batch_size)
#      86 output = activations[-1]
#      88 # Compute loss
# ---> 89 loss = DnnLib.cross_entropy(output, y_batch)
#      90 epoch_loss += loss
#      92 # Backward pass
#
# AttributeError: module 'DnnLib' has no attribute 'cross_entropy'

# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO CON ADAM OPTIMIZER
# ==================================================
# Arquitectura: 784 -> 128 -> 10
# Optimizador: Adam (learning_rate=0.001)
# Batch size: 128
# Épocas: 3
# ==================================================
# ✅ Datos MNIST cargados:
#    Entrenamiento: (60000, 784)
#    Prueba: (10000, 784)
# 🚀 Entrenando con Adam Optimizer
# ==================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:218
#     215     print("✅ Entrenamiento completado exitosamente!")
#     217 if __name__ == "__main__":
# --> 218     main()
#
# File /app/parte4_comparativa_fija.py:193, in main()
#     187 layers = [
#     188     DnnLib.DenseLayer(784, 128, DnnLib.ActivationType.RELU),
#     189     DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     190 ]
#     192 # 3. Entrenar con Adam
# --> 193 loss_history, acc_history = train_with_adam(
#     194     layers, X_train, y_train, X_test, y_test, epochs=3, batch_size=128
#     195 )
#     197 # 4. Evaluación final
#     198 final_accuracy = evaluate_accuracy(layers, X_test, y_test)
#
# File /app/parte4_comparativa_fija.py:111, in train_with_adam(layers, X_train, y_train, X_test, y_test, epochs, batch_size)
#     109 # Propagación hacia atrás
#     110 for i in reversed(range(len(layers))):
# --> 111     grad = layers[i].backward(grad)
#     112     layer_gradients.insert(0, grad)
#     114 # Adam update para cada capa
#
# AttributeError: 'DnnLib.DenseLayer' object has no attribute 'backward'

# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO CON ADAM OPTIMIZER
# ==================================================
# Arquitectura: 784 -> 128 -> 10
# Optimizador: Adam (learning_rate=0.001)
# Batch size: 128
# Épocas: 3
# ==================================================
# ✅ Datos MNIST cargados:
#    Entrenamiento: (60000, 784)
#    Prueba: (10000, 784)
# 🚀 Entrenando con Adam Optimizer
# ==================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:245
#     242     print("✅ Entrenamiento completado exitosamente!")
#     244 if __name__ == "__main__":
# --> 245     main()
#
# File /app/parte4_comparativa_fija.py:220, in main()
#     214 layers = [
#     215     DnnLib.DenseLayer(784, 128, DnnLib.ActivationType.RELU),
#     216     DnnLib.DenseLayer(128, 10, DnnLib.ActivationType.SOFTMAX)
#     217 ]
#     219 # 3. Entrenar con Adam
# --> 220 loss_history, acc_history = train_with_adam(
#     221     layers, X_train, y_train, X_test, y_test, epochs=3, batch_size=128
#     222 )
#     224 # 4. Evaluación final
#     225 final_accuracy = evaluate_accuracy(layers, X_test, y_test)
#
# File /app/parte4_comparativa_fija.py:141, in train_with_adam(layers, X_train, y_train, X_test, y_test, epochs, batch_size)
#     139     # Preparar gradiente para capa anterior (si no es la primera)
#     140     if i > 0:
# --> 141         current_grad = np.dot(current_grad, layer.weights.T)
#     143 # Adam update para cada capa
#     144 for i, layer in enumerate(layers):
#
# ValueError: shapes (128,10) and (128,10) not aligned: 10 (dim 1) != 128 (dim 0)
