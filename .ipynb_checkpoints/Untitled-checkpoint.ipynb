# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO CON ADAM OPTIMIZER
# ...
# Misma configuración que el Ing. Deras
# ...
# ✅ Datos MNIST cargados:
#    Entrenamiento: (60000, 28, 28) imágenes
#    Prueba: (10000, 28, 28) imágenes
# ✅ Datos preprocesados (/255.0 y one-hot encoding)
# ✅ Pesos inicializados con He Initialization
# 🚀 Iniciando entrenamiento (3 épocas)
# ...
# Arquitectura: 784 -> 128 -> 10
# Batch size: 128
# Learning rate: 0.001
# Optimizador: Adam
# ...
# Epoch 01 | Loss: 0.3606 | Train Acc: 0.9460 | Test Acc: 0.9426
# Epoch 02 | Loss: 0.1666 | Train Acc: 0.9608 | Test Acc: 0.9553
# Epoch 03 | Loss: 0.1186 | Train Acc: 0.9729 | Test Acc: 0.9665
# ...
# 🎯 TEST ACCURACY: 0.9665 (96.65%)
# 💾 Modelo exportado a: exercise4models/mnist_mlp_own_model.json
#
# ...
# 📊 RESUMEN DEL ENTRENAMIENTO:
# ...
# Epoch 01 | Loss: 0.3606 | Test Acc: 0.9426
# Epoch 02 | Loss: 0.1666 | Test Acc: 0.9553
# Epoch 03 | Loss: 0.1186 | Test Acc: 0.9665
# ...
# Test Accuracy: 0.9665
# Model exported to exercise4models/mnist_mlp_own_model.json
# ...

# %%
# %run parte4_comparativa_fija
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File /usr/local/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'parte4_comparativa_fija'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'parte4_comparativa_fija')
#
# ...

# %%
# %run parte4_comparativa_fija
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File /usr/local/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'parte4_comparativa_fija'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_line_magic('run', 'parte4_comparativa_fija')
#
# ...

# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO CON ADAM OPTIMIZER
# ...
# Misma configuración que el Ing. Deras
# ...
# ✅ Datos MNIST cargados:
#    Entrenamiento: (60000, 28, 28) imágenes
#    Prueba: (10000, 28, 28) imágenes
# ✅ Datos preprocesados (/255.0 y one-hot encoding)
# ✅ Pesos inicializados con He Initialization
# 🚀 Iniciando entrenamiento (3 épocas)
# ...
# Arquitectura: 784 -> 128 -> 10
# Batch size: 128
# Learning rate: 0.001
# Optimizador: Adam
# ...
# Epoch 01 | Loss: 0.3602 | Train Acc: 0.9444 | Test Acc: 0.9437
# Epoch 02 | Loss: 0.1635 | Train Acc: 0.9653 | Test Acc: 0.9624
# Epoch 03 | Loss: 0.1171 | Train Acc: 0.9735 | Test Acc: 0.9674
# ...
# 🎯 TEST ACCURACY: 0.9674 (96.74%)
# 💾 Modelo exportado a: exercise4models/mnist_mlp_own_model.json
#
# ...
# 📊 RESUMEN DEL ENTRENAMIENTO:
# ...
# Epoch 01 | Loss: 0.3602 | Test Acc: 0.9437
# Epoch 02 | Loss: 0.1635 | Test Acc: 0.9624
# Epoch 03 | Loss: 0.1171 | Test Acc: 0.9674
# ...
# Test Accuracy: 0.9674
# Model exported to exercise4models/mnist_mlp_own_model.json
# ...

# %%
# %run parte4_comparativa_fija
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File /usr/local/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'parte4_comparativa_fija'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_line_magic('run', 'parte4_comparativa_fija')
#
# ...

# %%
# %run parte4_comparativa_fija
# Out:
# 🧠 ENTRENAMIENTO CON ADAM OPTIMIZER
# ...
# Misma configuración que el Ing. Deras
# ...
# ✅ Datos MNIST cargados:
#    Entrenamiento: (60000, 28, 28) imágenes
#    Prueba: (10000, 28, 28) imágenes
# ✅ Datos preprocesados (/255.0 y one-hot encoding)
# ✅ Pesos inicializados con He Initialization
# 🚀 Iniciando entrenamiento (3 épocas)
# ...
# Arquitectura: 784 -> 128 -> 10
# Batch size: 128
# Learning rate: 0.001
# Optimizador: Adam
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:310
#     307     print("✅ Entrenamiento completado exitosamente!")
#     309 if __name__ == "__main__":
# --> 310     main()
#
# File /app/parte4_comparativa_fija.py:283, in main()
#     280 trainer.initialize_weights()
#     282 # 4. Entrenar modelo (3 épocas)
# --> 283 losses, accuracies = trainer.train()
#     285 # 5. Evaluar precisión final
# ...

# %%
# %run parte4_comparativa_fija
# Out:
#  ENTRENAMIENTO CON ADAM OPTIMIZER
# ...
# Misma configuración
# ...
#  Datos MNIST cargados:
#    Entrenamiento: (60000, 28, 28) imágenes
#    Prueba: (10000, 28, 28) imágenes
#  Datos preprocesados (/255.0 y one-hot encoding)
#  Pesos inicializados con He Initialization
#  Iniciando entrenamiento (3 épocas)
# ...
# Arquitectura: 784 -> 128 -> 10
# Batch size: 128
# Learning rate: 0.001
# Optimizador: Adam
# ...
# Epoch 01 | Loss: 0.3598 | Train Acc: 0.9480 | Test Acc: 0.9447
# Epoch 02 | Loss: 0.1635 | Train Acc: 0.9668 | Test Acc: 0.9631
# Epoch 03 | Loss: 0.1166 | Train Acc: 0.9718 | Test Acc: 0.9646
# ...
#  TEST ACCURACY: 0.9646 (96.46%)
#  Modelo exportado a: exercise4models/mnist_mlp_own_model.json
#
# ...
#  RESUMEN DEL ENTRENAMIENTO:
# ...
# Epoch 01 | Loss: 0.3598 | Test Acc: 0.9447
# Epoch 02 | Loss: 0.1635 | Test Acc: 0.9631
# Epoch 03 | Loss: 0.1166 | Test Acc: 0.9646
# ...
# Test Accuracy: 0.9646
# Model exported to exercise4models/mnist_mlp_own_model.json
#  Entrenamiento completado exitosamente!

# %%
# %run parte4
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File /usr/local/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'parte4'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('run', 'parte4')
#
# ...

# %%
# %run parte4_comparativa_fija
# Out:
#  ENTRENAMIENTO CON ADAM OPTIMIZER
# ...
# Misma configuración
# ...
#  Datos MNIST cargados:
#    Entrenamiento: (60000, 28, 28) imágenes
#    Prueba: (10000, 28, 28) imágenes
#  Datos preprocesados (/255.0 y one-hot encoding)
#  Pesos inicializados con He Initialization
#  Iniciando entrenamiento (3 épocas)
# ...
# Arquitectura: 784 -> 128 -> 10
# Batch size: 128
# Learning rate: 0.001
# Optimizador: Adam
# ...
# Epoch 01 | Loss: 0.3521 | Train Acc: 0.9485 | Test Acc: 0.9469
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /app/parte4_comparativa_fija.py:310
#     307     print(" Entrenamiento completado exitosamente!")
#     309 if __name__ == "__main__":
# --> 310     main()
#
# File /app/parte4_comparativa_fija.py:283, in main()
#     277 trainer.preprocess_data()
#     280 trainer.initialize_weights()
# --> 283 losses, accuracies = trainer.train()
# ...

# %%
# %run evaluar_pretrained.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File /usr/local/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'evaluar_pretrained.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'evaluar_pretrained.py')
#
# ...
